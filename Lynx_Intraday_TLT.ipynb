# %%
# Out:
# 100% Time: 0:00:06|###########################################################|
# Entire data start date: 2004-01-02
# Entire data end date: 2017-08-30
#
#
# Backtest Months: 163
# Performance statistics   Backtest
# annual_return                0.08
# cum_returns_final            1.92
# annual_volatility            0.09
# sharpe_ratio                 0.90
# calmar_ratio                 0.63
# stability_of_timeseries      0.94
# max_drawdown                -0.13
# omega_ratio                  1.21
# sortino_ratio                1.36
# skew                         0.26
# kurtosis                    10.37
# tail_ratio                   1.17
# common_sense_ratio           1.27
# gross_leverage               0.47
# information_ratio           -0.00
# alpha                        0.07
# beta                         0.15
# Worst drawdown periods net drawdown in %  peak date valley date recovery date  \
# 0                                  12.90 2008-12-19  2009-08-17    2010-09-13
# ...
