# %%
# Out:
# 100% Time: 0:00:01|###########################################################|
# Entire data start date: 2011-01-03
# Entire data end date: 2017-08-30
#
#
# Backtest Months: 79
# Performance statistics   Backtest
# annual_return                0.09
# cum_returns_final            0.77
# annual_volatility            0.08
# sharpe_ratio                 1.16
# calmar_ratio                 0.72
# stability_of_timeseries      0.97
# max_drawdown                -0.12
# omega_ratio                  1.31
# sortino_ratio                1.72
# skew                        -0.59
# kurtosis                    19.62
# tail_ratio                   1.32
# common_sense_ratio           1.44
# gross_leverage               0.40
# information_ratio           -0.03
# alpha                        0.04
# beta                         0.40
# Worst drawdown periods net drawdown in %  peak date valley date recovery date  \
# 0                                  12.50 2011-07-21  2011-08-08    2012-07-03
# ...
